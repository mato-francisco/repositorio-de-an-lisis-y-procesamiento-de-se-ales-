# %% [markdown]
# # TS1:sintesis de señales
# ### Francisco Mato
# ## Introduccion
# para poder sintetizar señales de forma digital es nesesario que la señal este dada de forma discreta, de este modo podemos hacernos una idea de como se veria la señal de forma continua. entonces como la señal es discreta, los datos van a estar compuestos por muestras. para saber cuantas muestras son nesesarias utilizaremos el teorema del muestreo el cual postula que :sea la señal de banda limitada tal que se determinan mediante sus muestras, y
# \begin{equation}
# ws>>2wm
# \end{equation}
# con ws la frecuencia de muestreo y wm la frecuencia de la señal, es posible reconstruir la señal original.
#
# la ortogonalidad o producto interno es una operacion la cual nos auda a calcular que tan perpendiculares (es decir que de 0) o independientes son dos sistemas.la opercaion ortogonalidad usada es de manera discreta por lo que sigue la suiguiente ecuacion:
# \begin{equation}
# producto \ interno=\sum_{n=-\infty}^{\infty}a[n]*^*b[n]
# \end{equation}
# como en nuestro caso no tenemos infinitas muestras debemos trabajar en periodos si queremos hallar que tan ortogonales son las señales, es decir en intervalos simetricos, ademas como todas la señales son reales podemos resumir a la ecuacion en:
# \begin{equation}
# producto \ interno=\sum_{n=0}^{T}a[n]*b[n]
# \end{equation}
# la correlcion es igual que la convolucion salvo que trabajos con una de las señales invertidas en tiempo con respecto a la convolucion, es decir:
# \begin{equation}
# correlacion[m]=\sum_{n=-N}^{N}a[n]*b[n-m]
# \end{equation}
# mientras que la autocorrelacion es la correlacion con una misma señal:
# \begin{equation}
# autocorrelacion[m]=\sum_{n=-N}^{N}a[n]*a[n-m]
# \end{equation}

# %% [markdown]
# ## Analisis y Discucion

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as sp

ff=2000
periodos_visible=3
N=1000
fs=N*ff/periodos_visible
deltaf=fs/N

t=np.arange(0,(N)/fs,1/fs)

seno=np.sin(ff*2*np.pi*t)

des_seno=(np.pi/2)*np.sin(ff*2*np.pi*t+np.pi/2)

modulado_seno=np.sin(ff*2*np.pi*t)*np.sin((ff/2)*2*np.pi*t)

potencia=(1/(N))*np.sum(np.abs(seno)**2)

recortada=np.clip(seno,-potencia*0.75,potencia*0.75)


cuadrada= sp.square(4000*2*np.pi * t)

t_pulso=np.arange(0,0.03,0.03/N)
pulso=np.zeros(N,dtype=float)
for k in np.arange(0,N):
    if(t_pulso[k]<0.01):
        
        pulso[k]=1
    else:
        pulso[k]=0

# %%
potencia=np.sum(np.abs(seno)**2)*(1/N)
print("muestras: ",N," tiempo entre muestras: ",1/fs," potencia: ",potencia)
plt.figure(1)
plt.plot(t,seno,linestyle='',marker=".")
plt.title('seno 2Khz')
plt.tight_layout() 
plt.xlabel('eje de tiempo [s]')
plt.ylabel('eje de potencia')

plt.draw()
# Out:
# muestras:  1000  tiempo entre muestras:  1.5e-06  potencia:  0.5

# %%
potencia=np.sum(np.abs(des_seno)**2)*(1/N)
print("muestras: ",N," tiempo entre muestras: ",1/fs," potencia: ",potencia)
plt.figure(1)
plt.plot(t,des_seno,linestyle='',marker=".")
plt.title('seno 2Khz modulado y aplificado pi/2')
plt.tight_layout() 
plt.xlabel('eje de tiempo [s]')
plt.ylabel('eje de potencia')

plt.draw()
# Out:
# muestras:  1000  tiempo entre muestras:  1.5e-06  potencia:  1.2337005501361695

# %%
potencia=np.sum(np.abs(modulado_seno)**2)*(1/N)
print("muestras: ",N," tiempo entre muestras: ",1/fs," potencia: ",potencia)
plt.figure(1)
plt.plot(t,modulado_seno,linestyle='',marker=".",label="modulada")
plt.plot(t,np.sin((ff/2)*2*np.pi*t),linestyle='',marker=".",label="sin modular")
plt.title('seno modulado de 2Khz por una mitad de frecuencia')
plt.tight_layout() 
plt.xlabel('eje de tiempo [s]')
plt.ylabel('eje de potencia')

plt.draw()
# Out:
# muestras:  1000  tiempo entre muestras:  1.5e-06  potencia:  0.25000000000000006

# %% [markdown]
# como vemos en el caso de una señal modulada por otra señal de distinta frecuencia, podemos ver que hay en una relacion de cuantos periodos de la senoidal de mayor frecuencia (2000hz) entra en medio periodo de la senoidal de menor frecuencia(1000hz). viendo el ejemplo del grafico de arriba podemos decir que la cantidad de periodos va a ser igual al periodo de la de mayor frecuencia dividido la mitad del periodo de la menor frecuencia
# \begin{equation}
# numero \ de\ periodos=\frac{periodo \ de\ mayor\ frecuencia}{\frac{periodo\ menor\ frecuencia}{2}}
# \end{equation}
# el numero de periodos no debe ser nesariamente un numero entero ya que puede entrar medio periodo o incluso 3/2 de un periodo.
# este resultado nos resulta util a la hora de entender como la senoidal modulada tiene una envolvente, la cual es el seno de menor frecuencia, la cual acota a la modulada.

# %%
potencia=np.sum(np.abs(recortada)**2)*(1/N)
print("muestras: ",N," tiempo entre muestras: ",1/fs," potencia: ",potencia)
plt.figure(1)
plt.plot(t,recortada,label='seno recortado',linestyle='',marker=".")
plt.plot(t,seno,label='seno',linestyle='',marker=".")
plt.legend()
plt.title('seno recortado al 75% de la potencia')
plt.tight_layout() 
plt.xlabel('eje de tiempo [s]')
plt.ylabel('eje de potencia')

plt.draw()
# Out:
# muestras:  1000  tiempo entre muestras:  1.5e-06  potencia:  0.1179140413508801

# %%
potencia=np.sum(np.abs(cuadrada)**2)*(1/N)
print("muestras: ",N," tiempo entre muestras: ",1/fs," potencia: ",potencia)
plt.figure(1)
plt.plot(t,cuadrada,linestyle='',marker=".")
plt.title('rectangular 4Khz')
plt.tight_layout() 
plt.xlabel('eje de tiempo [s]')
plt.ylabel('eje de potencia')

plt.draw()
# Out:
# muestras:  1000  tiempo entre muestras:  1.5e-06  potencia:  1.0

# %%
potencia=np.sum(np.abs(pulso)**2)*(1/N)
print("muestras: ",N," tiempo entre muestras: 30us potencia: ",potencia)
plt.figure(1)
plt.plot(t_pulso,pulso,linestyle='',marker=".")
plt.title('pulso de 10ms')
plt.tight_layout() 
plt.xlabel('eje de tiempo [s]')
plt.ylabel('eje de potencia')

plt.draw()
# Out:
# muestras:  1000  tiempo entre muestras: 30us potencia:  0.334

# %%
prointerno_senoXdes_seno=np.inner(seno,des_seno)
print("ortogonalida seno/seno_desfasado")
print(prointerno_senoXdes_seno)
print("")
prointerno_senoXmodulado_seno=np.inner(seno,modulado_seno)
print("ortogonalida seno/seno modulado")
print(prointerno_senoXmodulado_seno)
print("")
prointerno_senoXrecortada=np.inner(seno,recortada)
print("ortogonalida seno/seno recortado")
print(prointerno_senoXrecortada)
print("")
prointerno_senoXcuadrada=np.inner(seno,cuadrada)
print("ortogonalida seno/señal cuadrada")
print(prointerno_senoXcuadrada)
print("")
prointerno_senoXpulso=np.inner(seno,pulso)
print("ortogonalida seno/pulso 10ms")
print(prointerno_senoXpulso)
# Out:
# ortogonalida seno/seno_desfasado
# 5.01577945843934e-14
#
# ortogonalida seno/seno modulado
# 113.17684847671818
#
# ortogonalida seno/seno recortado
# 233.01281443212565
#
# ortogonalida seno/señal cuadrada
# 7.4346778733414e-14
#
# ortogonalida seno/pulso 10ms
# -0.0020944088830811003

# %% [markdown]
# como vimos el producto interno nos da que tan ortogonales son dos señales, mientras mas se acerque el producto ineterno al 0 podemos decir que tan ortogonales son las dos señales.analizando cada caso por separado podemos conlcuir que:
#
# $\color{red} 1er \ conclucion:$ el producto interno de las señales las cuales estan desfadas $\pi/2$ son mas ortogonales, esto cobra sentido cuando pensamos que el seno desfasado $\pi/2$ se asemeja al coseno y por definicion el seno y el coseno son ortogonales.  esto se ve reflejado en el producto interno estre el seno y el seno desfasado y modulado $\pi/2$, el cual dio como resultado un valor que tiene -14 ordenes de magnitud,por lo que aproxima bastante al 0.
# algo parecido sucede con la señal cuadrada de 4khz, al ser que la señal cuadrada empieza en el maximo mientras que la señal de seno empieza en el 0 podemos decir que hay un cierto desfasaje.
#
# $\color{red} 2da \ conclucion:$la señales de igual fase tienden a la energia del sistema, es decir que ambas señales son dependientes entre si. esto se ve en el producto interno entre el seno y la recortada o el seno con la modulada, ambos presentan la misma fase con respecto al seno original y su producto es mucho mayor que 0.

# %%
plt.figure(1)

plt.subplot(2,3,1)
plt.plot(np.correlate(seno, seno,mode="full"),linestyle='',marker=".")
plt.title('seno/seno')

plt.subplot(2,3,2)
plt.plot(np.correlate(seno, des_seno,mode="full"),linestyle='',marker=".")
plt.title('seno/seno amplificado')

plt.subplot(2,3,3)
plt.plot(np.correlate(seno, modulado_seno,mode="full"),linestyle='',marker=".")
plt.title('seno/seno modulado')

plt.subplot(2,3,4)
plt.plot(np.correlate(seno, recortada,mode="full"),linestyle='',marker=".")
plt.title('seno/recortado')

plt.subplot(2,3,5)
plt.plot(np.correlate(seno, cuadrada,mode="full"),linestyle='',marker=".")
plt.title('seno/cuadrada')

plt.subplot(2,3,6)
plt.plot(np.correlate(seno, pulso,mode="full"),linestyle='',marker=".")
plt.title('seno/pulso')

plt.tight_layout() 

plt.draw()

# %% [markdown]
# en la imagen anterior podemos ver las diferentes señales correlacionadas con el seno orignal de 2khz. en cada grafico podemos ver que hay etapas transitorias, la cuales son generadas debido a que la funcion correlate  utiliza el mismo principio que convolve, el cual es que utiliza la tranformada rapida de fourier para hacer la convolucion, esto repercute en que en cada señal hay una señal implicita la cual es una rectangular que va de 0 a N y maximo 1, entonces al convolucionar las señales original tambien estamos convolucionando dos señales rectangulares formando asi la envolvente con forma de rombo para el caso del seno autocorrelacionado ysus vairantes (recortado, desfasado).
# la covolucion nos ayuda a entender que tan semejantes son las señales entre si. esto lo hace a partir de desfasar una señal de la otra y calcular el producto interno entre la señal original y la desfasada, eso explica el porque en la muestra N(1000) la correlacion es igual al producto interno de la señales utilizadas.

# %% [markdown]
# \begin{equation}
# 2*\sin(\alpha)*\sin(\beta)=\cos(\alpha-\beta)-\cos(\alpha+\beta)
# \end{equation}
# sabiendo que
# \begin{equation}
# \sin(\alpha)=\frac{e^{i*\alpha}-e^{-i*\alpha}}{2i} \ y \ \cos(\alpha)=\frac{e^{i*\alpha}+e^{-i*\alpha}}{2}
# \end{equation}
# sustituimos el seno de alpha y de beta
# \begin{equation}
# 2*\frac{e^{i*\alpha}-e^{-i*\alpha}}{2i}*\frac{e^{i*\beta}-e^{-i*\beta}}{2i}
# \end{equation}
# \begin{equation}
# \frac{e^{i*\alpha}*e^{i*\beta}-e^{i*\alpha}*e^{-i*\beta}-e^{-i*\alpha}*e^{i*\beta}+e^{-i*\alpha}*e^{-i*\beta}}{-2}
# \end{equation}
# \begin{equation}
# \frac{e^{i*(\alpha+\beta)}-e^{i*(\alpha-\beta)}-e^{i*(-\alpha+\beta)}+e^{-i*(\alpha+\beta)}}{-2}
# \end{equation}
# \begin{equation}
# \frac{e^{i*(\alpha+\beta)}+e^{-i*(\alpha+\beta)}}{-2}+\frac{-e^{i*(\alpha-\beta)}-e^{-i*(\alpha-\beta)}}{-2}
# \end{equation}
# \begin{equation}
# \frac{e^{i*(\alpha+\beta)}+e^{-i*(\alpha+\beta)}}{-2}+\frac{e^{i*(\alpha-\beta)}+e^{-i*(\alpha-\beta)}}{2}
# \end{equation}
# y por la igualda anteriormente mencionada
# \begin{equation}
# -\cos(\alpha+\beta)+\cos(\alpha-\beta)
# \end{equation}

# %%
beta=1000
alpha=2*beta*2*np.pi*t
signal_a=2*np.sin(alpha)*np.sin(beta)
signal_b=np.cos((alpha-beta))-np.cos((alpha+beta))
plt.figure(1)
plt.plot(t,signal_a,linestyle='',marker="x",label="2*sin(alpha)*sin(beta)")
plt.plot(t,signal_b,linestyle='',marker=".",label="cos(alpha-beta)-cos(alpha+beta)")
plt.tight_layout() 
plt.legend()
plt.xlabel('eje de tiemp [s]')
plt.ylabel('eje de potencia')
plt.draw()

# %% [markdown]
# ## conclusion

# %% [markdown]
# en el trabajo se utilizaron varias señales para ver como respoden a ciertas operaciones (producto interno, correlacion) estas  señales y poder llegar a enterderlas.
#
# una de ellas fue el producto interno el cual nos da la idea de ortogonalidad entre dos señales, al comparar todas las señales con la senoidal de 4khz observamos que algunas señales son mas ortogonales que otras con respecto al seno, este resultado nos interesa a la hora de hacer una tranformada de fourier debido que en la tranformada multiplicamos por una exponencial compleja, que en el fondo es un seno imaginario mas un coseno , y luego integramos (en el mundo continuo) o sumamos (en el mundo discreto), por lo que en el fondo estamos haciendo un producto interno dentro de la tranformada,de forma que podemos decir que la ortogonalidad de señales esta de algun modo relacionada con la fase de la tranformada de fourier.
#
# otras de las operaciones observadas fue la correlacion. la cual ,como previamente habiamos dicho,da la idea de que tan realcionadas estan la señales, siendo que en los maximos es cuando mayor semejansa se tiene. esta operacion nos puede resultar util en el analisis de señales con ruido para encontrar para encotrar un recorte donde el ruido sea lo menor posible
#
# por ultimo se comprobo que resultados teorico como identades trigonometricas siguen siendo validas en el analisis de señales.
